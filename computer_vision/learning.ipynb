# %%
import pandas as pd
import numpy as np
import cv2
import matplotlib.pyplot as plt

# %%
image = cv2.imread('./images/mnist.png')

# %%
blur = cv2.GaussianBlur(image, (5, 5), 0)

# %%
cv2.imshow("Original Image", blur)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# ### Using CNNs for object recognition
